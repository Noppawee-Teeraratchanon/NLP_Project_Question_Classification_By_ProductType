# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

# %%
path_list = ['qa_Appliances.json.gz', 'qa_Arts_Crafts_and_Sewing.json.gz', 'qa_Automotive.json.gz', 'qa_Baby.json.gz',
             'qa_Beauty.json.gz', 'qa_Cell_Phones_and_Accessories.json.gz', 'qa_Clothing_Shoes_and_Jewelry.json.gz',
             'qa_Electronics.json.gz', 'qa_Grocery_and_Gourmet_Food.json.gz', 'qa_Health_and_Personal_Care.json.gz',
             'qa_Home_and_Kitchen.json.gz', 'qa_Industrial_and_Scientific.json.gz', 'qa_Musical_Instruments.json.gz',
             'qa_Office_Products.json.gz', 'qa_Patio_Lawn_and_Garden.json.gz', 'qa_Pet_Supplies.json.gz', 'qa_Software.json.gz',
             'qa_Sports_and_Outdoors.json.gz', 'qa_Tools_and_Home_Improvement.json.gz', 'qa_Toys_and_Games.json.gz',
             'qa_Video_Games.json.gz']

samples = []

for p in path_list:
    df = getDF(f'data/whole_data/{p}')
    # Select only the feature that we use

    # # Separate dataframe into two based on the classes
    # class_yesno = df[df['questionType']=="yes/no"]
    # class_open = df[df['questionType']=="open-ended"]

    # sample_class_yesno = class_yesno.sample(n=250)
    # sample_class_open = class_open.sample(n=250)

    # Concatenate the sampled dataframes
    # sample = pd.concat([sample_class_yesno, sample_class_open])
    samples.append(df)

# Create dataframe
df_sample = pd.concat(samples)

# %%
df_sample
# Out:
#       questionType        asin    answerTime      unixTime  \
# 0           yes/no  B00004U9JP  Jun 27, 2014  1.403852e+09
# 1       open-ended  B00004U9JP  Apr 28, 2014  1.398668e+09
# 2           yes/no  B00004U9JP  Aug 25, 2014  1.408950e+09
# 3           yes/no  B00004U9JP   Nov 3, 2014  1.415002e+09
# 4       open-ended  B00004U9JP  Jun 21, 2014  1.403334e+09
# ...            ...         ...           ...           ...
# 13302       yes/no  B00KGGJPYA  Nov 26, 2014  1.416989e+09
# 13303       yes/no  B00KGGJPYA  Oct 19, 2014  1.413702e+09
# 13304   open-ended  B00KGGJPYA  Oct 15, 2014  1.413356e+09
# 13305       yes/no  B00KGGJPYA  Jul 15, 2014  1.405408e+09
# 13306   open-ended  B00KGGJPYA   Jul 7, 2014  1.404716e+09
#
#                                                 question answerType  \
# 0      I have a 9 year old Badger 1 that needs replac...          ?
# 1                                           model number        NaN
# 2      can I replace Badger 1 1/3 with a Badger 5 1/2...          ?
# 3      Does this come with power cord and dishwasher ...          ?
# 4      loud noise inside when turned on. sounds like ...        NaN
# ...                                                  ...        ...
# 13302  Does the adaptor cord for the iPhone 5 work wi...          N
# 13303                       will it charge a kidle fire?          Y
# 13304           What are the dimensions of this product?        NaN
# 13305  Does this have connector for 5C? I think 5C is...          ?
# 13306  so I just bought the Gembonics Battery Back up...        NaN
#
#                                                   answer
# 0       I replaced my old one with this without a hitch.
# 1      This may help InSinkErator Model BADGER-1: Bad...
# 2      Plumbing connections will vary with different ...
# 3      It does not come with a power cord. It does co...
# 4      Check if you dropped something inside.Usually ...
# ...                                                  ...
# 13302                                                 No
# 13303  Simply answered, yes. It comes with a 3-in-1 a...
# 13304                                  4 by 1 1/2 inches
# 13305  I was able to charge Gembonics battery with iP...
# 13306  The Gembonics charger comes with a 3-in-1 cabl...
#
# [1396896 rows x 7 columns]

# %%
df_sample.to_csv('data/pre-category/all_data.csv', index=False)
